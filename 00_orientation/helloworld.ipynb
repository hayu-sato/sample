# %%
print("Hello! World!")
# Out:
# Hello! World!

# %% [markdown]
# # レッスン０
# -VS Codeの基本的な書き方
# 1. a
# 2. i
#
# - ai
#   - ai
# -----
#
# | 見出し1 | 見出し2 |
# | ------- | ------- |
# | データ1 | データ2 |
# | データ3 | データ4 |
